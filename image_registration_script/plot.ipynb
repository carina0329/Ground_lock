# %%
import matplotlib.pyplot as plt

# %%
registered_coors = [(-88.23452136878164, 40.06596494366363), (-88.15302130894966, 40.065125139696576), (-88.23291494897474, 40.15088652559685), (-88.15163267105038, 40.15003388309055)]
registered_coors_lst_x = [x[0] for x in registered_coors]
registered_coors_lst_y = [x[1] for x in registered_coors]

# %%
ground_truth_coords = [[-88.232948, 40.0928725113763], [-88.2149950203898, 40.157356], [-88.19617606715701, 40.157356], [-88.153053, 40.15010216317001], [-88.153053, 40.073257], [-88.232948, 40.073257], [-88.232948, 40.0928725113763]]
gtruth_coors_lst_x = [x[0] for x in ground_truth_coords]
gtruth_coors_lst_y = [x[1] for x in ground_truth_coords]

# %%
plt.plot(registered_coors_lst_y,registered_coors_lst_x)

# %%
plt.plot(gtruth_coors_lst_y,gtruth_coors_lst_x)
